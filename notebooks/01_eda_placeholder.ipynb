# %% [markdown]
# # PhytoSense — Exploratory Data Analysis
# Placeholder notebook. Load `backend/data/manifest_sample.csv`, inspect class balance, environmental feature distributions, and sample leaf images before training.

# %%
import pandas as pd
df = pd.read_csv('../backend/data/manifest_sample.csv')
df.describe(include='all')
